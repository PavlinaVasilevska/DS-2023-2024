# %% [markdown]
# #Task 1:
# This dataset includes scores from three test scores of students at a (fictional) public school and a variety of personal and socio-economic factors that may have interaction effects upon them.
# Column description:
# 1.  `Gender`: Gender of the student (male/female)
# 2.  `EthnicGroup`: Ethnic group of the student (group A to E)
# 3.  `ParentEduc`: Parent(s) education background (from some_highschool to master's degree)
# 4.  `LunchType`: School lunch type (standard or free/reduced)
# 5.  `TestPrep`: Test preparation course followed (completed or none)
# 6.  `ParentMaritalStatus`: Parent(s) marital status (married/single/widowed/divorced)
# 7.  `PracticeSport`: How often the student parctice sport (never/sometimes/regularly))
# 8.  `IsFirstChild`: If the child is first child in the family or not (yes/no)
# 9.  `NrSiblings`: Number of siblings the student has (0 to 7)
# 10. `TransportMeans`: Means of transport to school (schoolbus/private)
# 11. `WklyStudyHours`: Weekly self-study hours(less that 5hrs; between 5 and 10hrs; more than 10hrs)
# 12. `MathScore`: math test score(0-100)
# 13. `ReadingScore`: reading test score(0-100)
# 13. `WritingScore`: writing test score(0-100)

# %% [markdown]
# #Download the dataset
# Run the cell below

# %%
# !gdown 1La5PlbYWPH1VyiE8Zq2BDAYWqtpd56Z2
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1La5PlbYWPH1VyiE8Zq2BDAYWqtpd56Z2
# To: /content/Expanded_data_with_more_features.csv
# 100% 2.91M/2.91M [00:00<00:00, 176MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read the dataset

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Expanded_data_with_more_features.csv')

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %% [markdown]
# #Visualization

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender']= le.fit_transform(df['Gender'])
df['EthnicGroup']= le.fit_transform(df['EthnicGroup'])
df['ParentEduc']= le.fit_transform(df['ParentEduc'])
df['LunchType']= le.fit_transform(df['LunchType'])
df['TestPrep']= le.fit_transform(df['TestPrep'])
df['ParentMaritalStatus']= le.fit_transform(df['ParentMaritalStatus'])
df['PracticeSport']= le.fit_transform(df['PracticeSport'])
df['IsFirstChild']= le.fit_transform(df['IsFirstChild'])
df['TransportMeans']= le.fit_transform(df['TransportMeans'])
df['WklyStudyHours']= le.fit_transform(df['WklyStudyHours'])

# %%
df.head()
# Out:
#    Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           0       0            5           1          1         1
# 1           1       0            2           4          1         2
# 2           2       0            1           3          1         1
# 3           3       1            0           0          0         1
# 4           4       1            2           4          1         1
#
#    ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# 0                    1              1             1         3.0
# 1                    1              2             1         0.0
# 2                    2              2             1         4.0
# 3                    1              0             0         1.0
# 4                    1              2             1         0.0
#
#    TransportMeans  WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0               1               1         71            71            74
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'EthnicGroup'}>,
#         <Axes: title={'center': 'ParentEduc'}>],
#        [<Axes: title={'center': 'LunchType'}>,
#         <Axes: title={'center': 'TestPrep'}>,
#         <Axes: title={'center': 'ParentMaritalStatus'}>,
#         <Axes: title={'center': 'PracticeSport'}>],
#        [<Axes: title={'center': 'IsFirstChild'}>,
#         <Axes: title={'center': 'NrSiblings'}>,
#         <Axes: title={'center': 'TransportMeans'}>,
#         <Axes: title={'center': 'WklyStudyHours'}>],
#        [<Axes: title={'center': 'MathScore'}>,
#         <Axes: title={'center': 'ReadingScore'}>,
#         <Axes: title={'center': 'WritingScore'}>, <Axes: >]], dtype=object)

# %%
df['Gender'].hist()
# Out:
# <Axes: >

# %%
df['EthnicGroup'].hist()
# Out:
# <Axes: >

# %%
df['WritingScore'].hist()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# #Missing Values & Textual data

# %%
missing_values_df = df.isnull().sum()
percentage = 100 * missing_values_df / len(df)

# %%
missing_values_df
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus       0
# PracticeSport             0
# IsFirstChild              0
# NrSiblings             1572
# TransportMeans            0
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
percentage
# Out:
# Unnamed: 0             0.000000
# Gender                 0.000000
# EthnicGroup            0.000000
# ParentEduc             0.000000
# LunchType              0.000000
# TestPrep               0.000000
# ParentMaritalStatus    0.000000
# PracticeSport          0.000000
# IsFirstChild           0.000000
# NrSiblings             5.130381
# TransportMeans         0.000000
# WklyStudyHours         0.000000
# MathScore              0.000000
# ReadingScore           0.000000
# WritingScore           0.000000
# dtype: float64

# %%
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

# %%
df_const=df.copy()

# %%
from sklearn.impute import SimpleImputer
main_imputer = SimpleImputer(strategy = 'most_frequent')
df_const.iloc[:,:] = main_imputer.fit_transform(df_const)
df_const.isnull().sum()
# Out:
# <ipython-input-187-e49428b0b8dc>:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_const.iloc[:,:] = main_imputer.fit_transform(df_const)
# Unnamed: 0             0
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %% [markdown]
# #Train - test split of the dataset (80:20 ratio)

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           0       0            5           1          1         1
# 1           1       0            2           4          1         2
# 2           2       0            1           3          1         1
# 3           3       1            0           0          0         1
# 4           4       1            2           4          1         1
#
#    ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# 0                    1              1             1         3.0
# 1                    1              2             1         0.0
# 2                    2              2             1         4.0
# 3                    1              0             0         1.0
# 4                    1              2             1         0.0
#
#    TransportMeans  WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0               1               1         71            71            74
# ...

# %%
df_copy=df.copy()

# %%
df_copy.iloc[:,1:-1]
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           0            5           1          1         1
# 1           0            2           4          1         2
# 2           0            1           3          1         1
# 3           1            0           0          0         1
# 4           1            2           4          1         1
# ...       ...          ...         ...        ...       ...
# 30636       0            3           2          1         1
# 30637       1            4           2          1         1
# 30638       0            5           2          0         0
# 30639       0            3           0          1         0
# 30640       1            1           4          1         1
#
#        ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# 0                        1              1             1         3.0
# 1                        1              2             1         0.0
# ...

# %%
df_copy['WritingScore']
# Out:
# 0        74
# 1        88
# 2        91
# 3        42
# 4        75
#          ..
# 30636    65
# 30637    51
# 30638    67
# 30639    93
# 30640    58
# Name: WritingScore, Length: 30641, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_const.iloc[:,1:-1],df_const['WritingScore'], test_size=0.2)

# %%
X_train
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 22119     0.0          3.0         5.0        1.0       0.0
# 7881      0.0          3.0         5.0        1.0       0.0
# 5817      1.0          2.0         2.0        1.0       1.0
# 4651      0.0          4.0         0.0        1.0       0.0
# 23315     1.0          3.0         2.0        1.0       0.0
# ...       ...          ...         ...        ...       ...
# 977       1.0          2.0         0.0        0.0       0.0
# 10635     1.0          2.0         5.0        1.0       0.0
# 27683     0.0          2.0         2.0        0.0       0.0
# 27518     0.0          0.0         4.0        0.0       0.0
# 23958     0.0          2.0         5.0        1.0       1.0
#
#        ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# 22119                  1.0            2.0           1.0         1.0
# 7881                   1.0            2.0           0.0         2.0
# ...

# %%
X_test
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 25017     1.0          2.0         2.0        1.0       1.0
# 29400     1.0          2.0         2.0        1.0       1.0
# 14442     1.0          3.0         2.0        1.0       0.0
# 12827     1.0          2.0         2.0        1.0       1.0
# 22807     0.0          2.0         3.0        1.0       1.0
# ...       ...          ...         ...        ...       ...
# 5584      1.0          3.0         4.0        0.0       1.0
# 3659      0.0          2.0         1.0        0.0       2.0
# 13673     1.0          1.0         4.0        1.0       0.0
# 19953     1.0          4.0         0.0        1.0       0.0
# 23325     1.0          2.0         0.0        1.0       1.0
#
#        ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# 25017                  1.0            3.0           0.0         2.0
# 29400                  1.0            2.0           0.0         1.0
# ...

# %%
Y_train
# Out:
# 22119    73.0
# 7881     81.0
# 5817     58.0
# 4651     97.0
# 23315    53.0
#          ...
# 977      68.0
# 10635    82.0
# 27683    87.0
# 27518    77.0
# 23958    73.0
# Name: WritingScore, Length: 24512, dtype: float64

# %%
Y_test
# Out:
# 25017    50.0
# 29400    61.0
# 14442    91.0
# 12827    56.0
# 22807    71.0
#          ...
# 5584     59.0
# 3659     65.0
# 13673    94.0
# 19953    85.0
# 23325    77.0
# Name: WritingScore, Length: 6129, dtype: float64

# %%
df['TestPrep'].value_counts()
# Out:
# 1    18856
# 0     9955
# 2     1830
# Name: TestPrep, dtype: int64

# %% [markdown]
# #Model training (Use KNN, Logistic regression or Linear regression)

# %% [markdown]
# #Model evaluation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(X_train, Y_train)

# %%
r_sq = model.score(X_train, Y_train)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.9335817725603832

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([45.13741647, 68.70737067, 88.93230243, ..., 87.21115174,
#        88.90190007, 80.92493414])

# %%
import numpy as np
import statsmodels.api as sm

x = sm.add_constant(X_train)
model = sm.OLS(Y_train, x)

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           WritingScore   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                 2.649e+04
# Date:                Thu, 23 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:38:05   Log-Likelihood:                -68629.
# No. Observations:               24512   AIC:                         1.373e+05
# Df Residuals:                   24498   BIC:                         1.374e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         68.3627      0.025   2689.492      0.000      68.313      68.413
# ...

# %%
x = sm.add_constant(X_train)

y_pred = results.predict(x)
print(y_pred)
# Out:
# [70.62832183 81.94184528 59.01653108 ... 89.63177963 77.30651839
#  76.69798074]
